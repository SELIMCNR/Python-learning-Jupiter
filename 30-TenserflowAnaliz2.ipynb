# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sbn

# %%
dataFrame = pd.read_excel("merc.xlsx")  # read excel file

# %%
dataFrame.head()
# Out:
#    year  price transmission  mileage  tax   mpg  engineSize
# 0  2005   5200    Automatic    63000  325  32.1         1.8
# 1  2017  34948    Automatic    27000   20  61.4         2.1
# 2  2016  49948    Automatic     6200  555  28.0         5.5
# 3  2016  61948    Automatic    16000  325  30.4         4.0
# 4  2016  73948    Automatic     4000  325  30.1         4.0

# %%
dataFrame.describe()  # veri seti hakkında bilgi verir
# Out:
#                year          price        mileage           tax           mpg  \
# count  13119.000000   13119.000000   13119.000000  13119.000000  13119.000000
# mean    2017.296288   24698.596920   21949.559037    129.972178     55.155843
# std        2.224709   11842.675542   21176.512267     65.260286     15.220082
# min     1970.000000     650.000000       1.000000      0.000000      1.100000
# 25%     2016.000000   17450.000000    6097.500000    125.000000     45.600000
# 50%     2018.000000   22480.000000   15189.000000    145.000000     56.500000
# 75%     2019.000000   28980.000000   31779.500000    145.000000     64.200000
# max     2020.000000  159999.000000  259000.000000    580.000000    217.300000
#
#          engineSize
# count  13119.000000
# mean       2.071530
# std        0.572426
# min        0.000000
# 25%        1.800000
# 50%        2.000000
# 75%        2.100000
# max        6.200000

# %%
dataFrame.isnull().sum()  # veri setindeki eksik veri sayısını verir
# Out:
# year            0
# price           0
# transmission    0
# mileage         0
# tax             0
# mpg             0
# engineSize      0
# dtype: int64

# %%
plt.figure(figsize=(7,5)) # grafiğin boyutunu belirler
sbn.displot(dataFrame["price"])  # fiyat dağılımını gösterir

# %%
plt.figure(figsize=(10, 5))
sbn.countplot(x="year", data=dataFrame)
# Out:
# <Axes: xlabel='year', ylabel='count'>

# %%
dataFrame.corr()  # korelasyon tablosu
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 dataFrame.corr()  # korelasyon tablosu
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\frame.py:10704, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10702 cols = data.columns
#   10703 idx = cols.copy()
# > 10704 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10706 if method == "pearson":
#   10707     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\frame.py:1889, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1887 if dtype is not None:
#    1888     dtype = np.dtype(dtype)
# ...

# %%
dataFrame.corr()["price"].sort_values()  # fiyat ile korelasyonu gösterir
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 dataFrame.corr(["price"]).sort_values()  # fiyat ile korelasyonu gösterir
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\frame.py:10704, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10702 cols = data.columns
#   10703 idx = cols.copy()
# > 10704 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10706 if method == "pearson":
#   10707     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\frame.py:1889, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1887 if dtype is not None:
#    1888     dtype = np.dtype(dtype)
# ...

# %%
sbn.scatterplot(x="mileage", y="price", data=dataFrame) # milaj ve fiyat arasındaki ilişkiyi gösterir
# Out:
# <Axes: xlabel='mileage', ylabel='price'>

# %%
dataFrame.sort_values("price", ascending=False).head(20)  # fiyatı en yüksek olan 20 aracı gösterir
# Out:
#        year   price transmission  mileage  tax   mpg  engineSize
# 6199   2020  159999    Semi-Auto     1350  145  21.4         4.0
# 10044  2020  154998    Automatic     3000  150  21.4         4.0
# 5      2011  149948    Automatic     3000  570  21.4         6.2
# 8737   2019  140319    Semi-Auto      785  150  22.1         4.0
# 6386   2018  139995    Semi-Auto    13046  145  21.4         4.0
# 8      2019  139948    Automatic    12000  145  21.4         4.0
# 9133   2019  139559    Semi-Auto     1000  145  22.1         4.0
# 8821   2020  138439    Semi-Auto     1000  145  22.1         4.0
# 5902   2018  135771    Semi-Auto    19000  145  21.4         4.0
# 7864   2018  135124    Semi-Auto    18234  150  21.4         4.0
# 8673   2019  134219    Semi-Auto     1000  145  24.8         4.0
# 6210   2019  129990    Automatic     1000  145  24.8         4.0
# 4759   2019  126000    Automatic      250  145  24.6         4.0
# ...

# %%
dataFrame.sort_values("price", ascending=True).head(20)  # fiyatı en düşük olan 20 aracı gösterir
# Out:
#        year  price transmission  mileage  tax   mpg  engineSize
# 11816  2003    650       Manual   109090  235  40.0         1.4
# 12008  2010   1350       Manual   116126  145  54.3         2.0
# 11765  2000   1490    Automatic    87000  265  27.2         3.2
# 11549  2002   1495    Automatic    13800  305  39.8         2.7
# 12594  2004   1495       Manual   119000  300  34.5         1.8
# 11174  2001   1695    Automatic   108800  325  31.7         3.2
# 12710  2006   1695    Automatic   153000  300  33.6         1.8
# 12766  2004   1780    Automatic   118000  265  41.5         2.2
# 12009  2007   1800    Automatic    84000  200  42.8         1.5
# 11764  1998   1990    Automatic    99300  265  32.1         2.3
# 11808  1998   1990    Automatic   113557  265  32.1         2.3
# 11383  2005   1995    Automatic   105000  260  43.5         2.1
# 11378  2004   1995    Semi-Auto   165000  330  20.0         3.7
# 11857  2002   2140    Automatic    52700  325  31.4         2.0
# ...

# %%
len(dataFrame)  # veri setindeki toplam veri sayısı
# Out:
# 13119

# %%
len(dataFrame) * 0.01  # veri setinin %99'unu almak için kaç veri alınmalı
# Out:
# 131.19

# %%
yuzdeDoksanDokuzDataFrame= dataFrame.sort_values("price", ascending=False).iloc[131:]  # fiyatı en yüksek olan 131 veriyi alır

# %%
yuzdeDoksanDokuzDataFrame.describe()  # yeni veri seti hakkında bilgi verir
# Out:
#                year         price        mileage           tax           mpg  \
# count  12988.000000  12988.000000   12988.000000  12988.000000  12988.000000
# mean    2017.281876  24074.926933   22132.741146    129.689714     55.437142
# std        2.228515   9866.224575   21196.776401     65.183076     15.025999
# min     1970.000000    650.000000       1.000000      0.000000      1.100000
# 25%     2016.000000  17357.500000    6322.000000    125.000000     45.600000
# 50%     2018.000000  22299.000000   15369.500000    145.000000     56.500000
# 75%     2019.000000  28706.000000   31982.250000    145.000000     64.200000
# max     2020.000000  65990.000000  259000.000000    580.000000    217.300000
#
#          engineSize
# count  12988.000000
# mean       2.050901
# std        0.532596
# min        0.000000
# 25%        1.675000
# 50%        2.000000
# 75%        2.100000
# max        6.200000

# %%
plt.figure(figsize=(7,5))
sbn.displot(yuzdeDoksanDokuzDataFrame["price"])  # fiyat dağılımını gösterir

# %%
dataFrame.describe()  # orjinal veri seti hakkında bilgi verir
# Out:
#                year          price        mileage           tax           mpg  \
# count  13119.000000   13119.000000   13119.000000  13119.000000  13119.000000
# mean    2017.296288   24698.596920   21949.559037    129.972178     55.155843
# std        2.224709   11842.675542   21176.512267     65.260286     15.220082
# min     1970.000000     650.000000       1.000000      0.000000      1.100000
# 25%     2016.000000   17450.000000    6097.500000    125.000000     45.600000
# 50%     2018.000000   22480.000000   15189.000000    145.000000     56.500000
# 75%     2019.000000   28980.000000   31779.500000    145.000000     64.200000
# max     2020.000000  159999.000000  259000.000000    580.000000    217.300000
#
#          engineSize
# count  13119.000000
# mean       2.071530
# std        0.572426
# min        0.000000
# 25%        1.800000
# 50%        2.000000
# 75%        2.100000
# max        6.200000

# %%
dataFrame.groupby("year").mean(["price"])  # yıllara göre fiyat ortalamalarını gösterir
# Out:
#              price       mileage         tax        mpg  engineSize
# year
# 1970  24999.000000  14000.000000  305.000000  39.200000    0.000000
# 1997   9995.000000  76000.000000  255.000000  28.200000    3.200000
# 1998   8605.000000  76347.750000  262.500000  28.925000    3.450000
# 1999   5995.000000  34000.000000  145.000000  24.600000    3.200000
# 2000   5743.333333  89648.666667  268.333333  26.333333    3.200000
# 2001   4957.900000  72955.100000  347.500000  28.140000    2.870000
# 2002   5820.444444  57391.111111  350.555556  27.877778    3.522222
# 2003   4878.000000  88777.714286  300.000000  29.485714    3.028571
# 2004   4727.615385  94363.461538  312.307692  31.838462    2.530769
# 2005   4426.111111  80651.333333  303.333333  35.344444    2.377778
# 2006   4036.875000  94347.375000  412.500000  34.375000    2.812500
# 2007   5136.045455  80309.000000  351.136364  36.363636    2.263636
# 2008   6967.437500  81442.437500  342.812500  34.343750    2.662500
# ...

# %%
yuzdeDoksanDokuzDataFrame.groupby("year").mean(["price"])  # yeni veri seti yıllara göre fiyat ortalamalarını gösterir
# Out:
#              price       mileage         tax        mpg  engineSize
# year
# 1970  24999.000000  14000.000000  305.000000  39.200000    0.000000
# 1997   9995.000000  76000.000000  255.000000  28.200000    3.200000
# 1998   8605.000000  76347.750000  262.500000  28.925000    3.450000
# 1999   5995.000000  34000.000000  145.000000  24.600000    3.200000
# 2000   5743.333333  89648.666667  268.333333  26.333333    3.200000
# 2001   4957.900000  72955.100000  347.500000  28.140000    2.870000
# 2002   5820.444444  57391.111111  350.555556  27.877778    3.522222
# 2003   4878.000000  88777.714286  300.000000  29.485714    3.028571
# 2004   4727.615385  94363.461538  312.307692  31.838462    2.530769
# 2005   4426.111111  80651.333333  303.333333  35.344444    2.377778
# 2006   4036.875000  94347.375000  412.500000  34.375000    2.812500
# 2007   5136.045455  80309.000000  351.136364  36.363636    2.263636
# 2008   6967.437500  81442.437500  342.812500  34.343750    2.662500
# ...

# %%
dataFrame1970sil=dataFrame[dataFrame.year != 1970]  # 1970 yılında olan verileri çıkarır

# %%
dataFrame1970sil.groupby("year").mean(["price"])  # 1970 yılında olan verileri çıkardıktan sonra yıllara göre fiyat ortalamalarını gösterir
# Out:
#              price       mileage         tax        mpg  engineSize
# year
# 1997   9995.000000  76000.000000  255.000000  28.200000    3.200000
# 1998   8605.000000  76347.750000  262.500000  28.925000    3.450000
# 1999   5995.000000  34000.000000  145.000000  24.600000    3.200000
# 2000   5743.333333  89648.666667  268.333333  26.333333    3.200000
# 2001   4957.900000  72955.100000  347.500000  28.140000    2.870000
# 2002   5820.444444  57391.111111  350.555556  27.877778    3.522222
# 2003   4878.000000  88777.714286  300.000000  29.485714    3.028571
# 2004   4727.615385  94363.461538  312.307692  31.838462    2.530769
# 2005   4426.111111  80651.333333  303.333333  35.344444    2.377778
# 2006   4036.875000  94347.375000  412.500000  34.375000    2.812500
# 2007   5136.045455  80309.000000  351.136364  36.363636    2.263636
# 2008   6967.437500  81442.437500  342.812500  34.343750    2.662500
# 2009   6166.764706  92207.941176  295.000000  38.147059    2.423529
# ...

# %%
dataFrame1970sil.head()
# Out:
#    year  price transmission  mileage  tax   mpg  engineSize
# 0  2005   5200    Automatic    63000  325  32.1         1.8
# 1  2017  34948    Automatic    27000   20  61.4         2.1
# 2  2016  49948    Automatic     6200  555  28.0         5.5
# 3  2016  61948    Automatic    16000  325  30.4         4.0
# 4  2016  73948    Automatic     4000  325  30.1         4.0

# %%
dataFrame1970sil= dataFrame1970sil.drop("transmission", axis=1)  # transmission sütununu çıkarır

# %%
y = dataFrame1970sil["price"].values  # fiyat sütununu y değişkenine atar
x = dataFrame1970sil.drop("price", axis=1).values  # fiyat sütununu çıkarır ve geri kalan verileri x değişkenine atar

# %%
y
# Out:
# array([ 5200, 34948, 49948, ..., 30999, 37990, 54999], dtype=int64)

# %%
x
# Out:
# array([[2.0050e+03, 6.3000e+04, 3.2500e+02, 3.2100e+01, 1.8000e+00],
#        [2.0170e+03, 2.7000e+04, 2.0000e+01, 6.1400e+01, 2.1000e+00],
#        [2.0160e+03, 6.2000e+03, 5.5500e+02, 2.8000e+01, 5.5000e+00],
#        ...,
#        [2.0190e+03, 1.1612e+04, 1.4500e+02, 4.1500e+01, 2.1000e+00],
#        [2.0190e+03, 2.4260e+03, 1.4500e+02, 4.5600e+01, 2.0000e+00],
#        [2.0190e+03, 2.0750e+03, 1.4500e+02, 5.2300e+01, 2.9000e+00]])

# %%
from sklearn.model_selection import train_test_split # veri setini train ve test olarak ayırır

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=10)  # veri setinin %70'ini train %30'unu test olarak ayırır

# %%
len(x_train)
# Out:
# 9182

# %%
len(x_test)
# Out:
# 3936

# %%
from sklearn.preprocessing import MinMaxScaler  # veri setini ölçeklendirir

# %%
scaler = MinMaxScaler()  # ölçeklendirme işlemi için değişken oluşturur

# %%
x_train = scaler.fit_transform(x_train)  # train veri setini ölçeklendirir

# %%
x_test = scaler.transform(x_test)  # test veri setini ölçeklendirir

# %%
from  keras.models import Sequential  # model oluşturmak için kullanılır

# %%
from keras.layers import Dense  # katman oluşturmak için kullanılır

# %%
model = Sequential()  # model oluşturur
# Out:
# WARNING:tensorflow:From C:\Users\btk02\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
model.add(Dense(12, activation="relu"))  # 12 nöronlu gizli katman ekler
model.add(Dense(12, activation="relu"))  # 12 nöronlu gizli katman ekler
model.add(Dense(12, activation="relu"))  # 12 nöronlu gizli katman ekler
model.add(Dense(12, activation="relu"))  # 12 nöronlu gizli katman ekler
model.add(Dense(1))  # çıkış katmanı ekler
model.compile(optimizer="adam", loss="mse")  # modeli derler
# Out:
# WARNING:tensorflow:From C:\Users\btk02\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
model.fit(x=x_train, y=y_train, validation_data=(x_test, y_test), batch_size=250, epochs=300)  # modeli eğitir #batch_size=250 : her bir adımda 250 veri alınır , validation_data=(x_test, y_test) : test veri seti ile modelin başarısını ölçer , epochs=300 : 300 kere eğitir
# Out:
# Epoch 1/300
# WARNING:tensorflow:From C:\Users\btk02\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 37/37 [==============================] - 2s 11ms/step - loss: 741596096.0000 - val_loss: 770440576.0000
# Epoch 2/300
# 37/37 [==============================] - 0s 4ms/step - loss: 741541888.0000 - val_loss: 770347200.0000
# Epoch 3/300
# 37/37 [==============================] - 0s 5ms/step - loss: 741366336.0000 - val_loss: 770030208.0000
# Epoch 4/300
# 37/37 [==============================] - 0s 4ms/step - loss: 740750336.0000 - val_loss: 768919616.0000
# Epoch 5/300
# 37/37 [==============================] - 0s 4ms/step - loss: 738689472.0000 - val_loss: 765339584.0000
# Epoch 6/300
# ...

# %%
kayipVerisi = pd.DataFrame(model.history.history)  # modelin eğitim verilerini kaydeder

# %%
kayipVerisi.head() # kayıp verilerini gösterir
# Out:
#           loss     val_loss
# 0  741596096.0  770440576.0
# 1  741541888.0  770347200.0
# 2  741366336.0  770030208.0
# 3  740750336.0  768919616.0
# 4  738689472.0  765339584.0

# %%
kayipVerisi.plot()  # kayıp verilerini gösterir
# Out:
# <Axes: >

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error  # hata hesaplamak için kullanılır

# %%
tahminDizisi = model.predict(x_test)  # test veri seti ile tahmin yapar
# Out:
# 123/123 [==============================] - 0s 2ms/step

# %%
tahminDizisi
# Out:
# array([[38867.53 ],
#        [30843.361],
#        [42104.42 ],
#        ...,
#        [23162.258],
#        [19025.729],
#        [20722.504]], dtype=float32)

# %%
mean_absolute_error(y_test, tahminDizisi)  # ortalama mutlak hata
# Out:
# 3465.9456706473497

# %%
dataFrame.describe()  # orjinal veri seti hakkında bilgi verir
# Out:
#                year          price        mileage           tax           mpg  \
# count  13119.000000   13119.000000   13119.000000  13119.000000  13119.000000
# mean    2017.296288   24698.596920   21949.559037    129.972178     55.155843
# std        2.224709   11842.675542   21176.512267     65.260286     15.220082
# min     1970.000000     650.000000       1.000000      0.000000      1.100000
# 25%     2016.000000   17450.000000    6097.500000    125.000000     45.600000
# 50%     2018.000000   22480.000000   15189.000000    145.000000     56.500000
# 75%     2019.000000   28980.000000   31779.500000    145.000000     64.200000
# max     2020.000000  159999.000000  259000.000000    580.000000    217.300000
#
#          engineSize
# count  13119.000000
# mean       2.071530
# std        0.572426
# min        0.000000
# 25%        1.800000
# 50%        2.000000
# 75%        2.100000
# max        6.200000

# %%
#şuanlık modelin başarısı %13 civarında 
#modelin başarısını arttırmak için epoch sayısını arttırabiliriz
#modelin başarısını arttırmak için daha fazla veri toplayabiliriz
#modelin başarısını arttırmak için daha fazla öznitelik ekleyebiliriz
#modelin başarısını arttırmak için daha farklı bir model kullanabiliriz veya modelden çıkarmalar yapılabiliri veri olarak

# %%
plt.scatter(y_test, tahminDizisi)  # gerçek fiyatlar ile tahmin edilen fiyatları karşılaştırır
plt.plot(y_test, y_test, "g-*")  # gerçek fiyatları gösterir

# %%
dataFrame
# Out:
#        year  price transmission  mileage  tax   mpg  engineSize
# 0      2005   5200    Automatic    63000  325  32.1         1.8
# 1      2017  34948    Automatic    27000   20  61.4         2.1
# 2      2016  49948    Automatic     6200  555  28.0         5.5
# 3      2016  61948    Automatic    16000  325  30.4         4.0
# 4      2016  73948    Automatic     4000  325  30.1         4.0
# ...     ...    ...          ...      ...  ...   ...         ...
# 13114  2020  35999    Automatic      500  145  55.4         2.0
# 13115  2020  24699    Automatic     2500  145  55.4         2.0
# 13116  2019  30999    Automatic    11612  145  41.5         2.1
# 13117  2019  37990    Automatic     2426  145  45.6         2.0
# 13118  2019  54999    Automatic     2075  145  52.3         2.9
#
# [13119 rows x 7 columns]

# %%
dataFrame.iloc[2]  # 2. indexdeki veriyi gösterir
# Out:
# year                 2016
# price               49948
# transmission    Automatic
# mileage              6200
# tax                   555
# mpg                  28.0
# engineSize            5.5
# Name: 2, dtype: object

# %%
yeniArabaSeries = dataFrame.drop("price", axis=1).iloc[2]  # 2. indexdeki verinin fiyat sütununu çıkarır

# %%
type(yeniArabaSeries)
# Out:
# pandas.core.series.Series

# %%
yeniArabaSeries = scaler.transform(yeniArabaSeries.values.reshape(-1,5))  # veriyi ölçeklendirir
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[103], line 1
# ----> 1 yeniArabaSeries = scaler.transform(yeniArabaSeries.values.reshape(-1,5))  # veriyi ölçeklendirir
#
# ValueError: cannot reshape array of size 6 into shape (5)

# %%
model.predict(yeniArabaSeries)  # tahmin yapar
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[104], line 1
# ----> 1 model.predict(yeniArabaSeries)  # tahmin yapar
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\tensorflow\python\framework\constant_op.py:103, in convert_to_eager_tensor(value, ctx, dtype)
# ...
