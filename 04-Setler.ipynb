# %%
benimListem = [1,2,3,1,2,3]

# %%
benimListem
# Out:
# [1, 2, 3, 1, 2, 3]

# %%
# Set koleksiyon tipinde tekrar eden veriler olmaz
# dönüşüm yapma koleksiyonlarda

# %%
benimListeSetim = set(benimListem)

# %%
type(benimListem)
# Out:
# list

# %%
type(benimListeSetim)
# Out:
# set

# %%
benimListeSetim
# Out:
# {1, 2, 3}

# %%
benimSet = {}

# %%
benimSet = {"a","b","c","a"}

# %%
type(benimSet)
# Out:
# set

# %%
benimSet ## tekrarlanan ifadeler yer almaz
# Out:
# {'a', 'b', 'c'}

# %%
bosListe = []

# %%
type(bosListe)
# Out:
# list

# %%
bosListe.append(1)

# %%
bosSozluk = {}

# %%
type(bosSozluk)
# Out:
# dict

# %%
bosSozluk["anahtarKelime"]=10

# %%
bosSozluk
# Out:
# {'anahtarKelime': 10}

# %%
benimBosSetim = set ()

# %%
benimBosSetim
# Out:
# set()

# %%
benimBosSetim.add(10)

# %%
benimBosSetim.add(10)

# %%
benimBosSetim.add(20)

# %%
benimBosSetim
# Out:
# {10, 20}

# %%
benimBosListem = list()

# %%
benimBosListem
# Out:
# []

# %%
benimBosListem.append(10)

# %%
benimBosListem
# Out:
# [10]

# %%
benimBosSozlugum = dict()

# %%
benimBosSozlugum["key"] = 3234

# %%
benimBosSozlugum
# Out:
# {'key': 3234}
